# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
batch1 = pd.read_csv('D:\ieee-mansb-victoris-2\IEEE_Victoris2_Filtration_train_data\Train_Batch_1.csv')
batch2 = pd.read_csv('D:\ieee-mansb-victoris-2\IEEE_Victoris2_Filtration_train_data\Train_Batch_2.csv')
batch3 = pd.read_csv('D:\ieee-mansb-victoris-2\IEEE_Victoris2_Filtration_train_data\Train_Batch_3.csv')

print("batch1", batch1.columns)
print("batch2", batch2.columns)
print("batch3", batch3.columns)
# Out:
# batch1 Index(['Unnamed: 0', 'Person Description', 'Place Code', 'Customer Order',
#        'Additional Features in market', 'Promotion Name', 'Store Kind',
#        'Store Sales', 'Store Cost', 'Product Weights Data in (KG)',
#        'Is Recyclable?', 'Min. Yearly Income', 'Store Area', 'Grocery Area',
#        'Frozen Area', 'Meat Area', 'Cost'],
#       dtype='object')
# batch2 Index(['Unnamed: 0', 'Person Description', 'Place Code', 'Customer Order',
#        'Additional Features in market', 'Promotion Name', 'Store Kind',
#        'Store Sales', 'Store Cost', 'Gross Weight', 'Net Weight',
#        'Is Recyclable?', 'Min. Person Yearly Income', 'Store Area',
#        'Grocery Area', 'Frozen Area', 'Meat Area', 'Cost'],
#       dtype='object')
# batch3 Index(['Unnamed: 0', 'Person%20Description', 'Place%20Code',
#        'Customer%20Order', 'Additional%20Features%20in%20market',
#        'Promotion%20Name', 'Store%20Kind', 'Store%20Sales', 'Store%20Cost',
# ...

# %%
def rename_columns(df):
    df.columns = df.columns.str.replace('%20', ' ')

# %%
merged_data = pd.concat([batch1, batch2, batch3], axis=0)

# %%
columns_batch1 = set(batch1.columns)
columns_batch2 = set(batch2.columns)
columns_batch3 = set(batch3.columns)

# %%
extra_columns_batch1 = columns_batch1.difference(merged_data.columns)
if extra_columns_batch1:
    print("Extra columns in Batch 1:", extra_columns_batch1)

# Check for extra columns in Batch 2
extra_columns_batch2 = columns_batch2.difference(merged_data.columns)
if extra_columns_batch2:
    print("Extra columns in Batch 2:", extra_columns_batch2)

# Check for extra columns in Batch 3
extra_columns_batch3 = columns_batch3.difference(merged_data.columns)
if extra_columns_batch3:
    print("Extra columns in Batch 3:", extra_columns_batch3)

# %%
merged_data.head()
# Out:
#   Unnamed: 0                                 Person Description Place Code  \
# 0    mc_ID_0  Single Female with four children, education: b...   H11go_ZA
# 1    mc_ID_1  Single Female with three children, education: ...   S04ne_WA
# 2    mc_ID_2  Married Male with two children, education: hig...   L05es_CA
# 3    mc_ID_3  Single Female with three children, education: ...   S03le_WA
# 4    mc_ID_4  Married Female with five children, education: ...   M10da_YU
#
#                                       Customer Order  \
# 0  Cleaning Supplies from Household department, O...
# 1  Snack Foods from Snack Foods department, Order...
# 2  Magazines from Periodicals department, Ordered...
# 3  Dairy from Dairy department, Ordered Brand : C...
# 4  Vegetables from Produce department, Ordered Br...
#
#                        Additional Features in market   Promotion Name  \
# 0  ['Video Store', 'Florist', 'Ready Food', 'Coff...        Dimes Off
# ...
